# %% [markdown]
# **PYTHON ASSIGNMENT**
#
# ---

# %% [markdown]
# 1. What is Python, and why is it popular ?
# ---
# - Python is programming language which is used to for data science , data anlaytics and many more
# - Why its popular ?
#  1. Its easy to understand
#  2. mostly used in industries because of simple syntax

# %% [markdown]
# 2. What is an interpreter in Python ?
# ---
# - Interpreter in Python are basically interpret code line by line

# %% [markdown]
# 3. What are pre-defined keywords in Python ?
# ---
# - The pre-defined keywords are the special types to words which is used to perform specific type of function

# %% [markdown]
# 4. Can keywords be used as variable names?
# ---
# - Yes , we can use BUT later it will create difficultly for python if we use same variable as keyword
# - print = "Hello"
# - print("print") # Print as keyword and variable , later it will creates alot difficult

# %% [markdown]
# 5. What is mutability in Python ?
# ---
# - Mutabaility is what we say that we can change value in object

# %% [markdown]
# 6.  Why are lists mutable, but tuples are immutable ?
# ---
# - List are mutable , which means we can access anytime and can change what ever we want . ex - mom's shopping bag
# - Tuple are immutable , which means we can't access or change what ever we want . ex - Addhar card , PAN card

# %% [markdown]
# 7. What is the difference between “==” and “is” operators in Python ?
# ---
# - "==" is equal too sign which means to show the two values are equal too each other , comparsion operator
# - "is" is an operator form identity operator which show the following elements is form container or not by using 'is'

# %% [markdown]
# 8. What are logical operators in Python ?
# ---
# - Logical operators are operators which checks boolean expression (True or False)
# - and , not , or are some logical operators

# %% [markdown]
# 9. What is type casting in Python ?
# ---
# - Type casting or type conversion is basically converting elements for 1 datatype to another

# %% [markdown]
# 10. What is the difference between implicit and explicit type casting ?
# ---
# - Implicit type casting - are built-In type casting in Python
# - Explicit type casting - are user-defined typecasting in Python

# %% [markdown]
# 11. What is the purpose of conditional statements in Python ?
# ---
# - Conditional Statements are statements where we express conditions to code

# %% [markdown]
# 12. How does the elif statement work ?
# ---
# - Elif statement is statement where we add 'if' more than once's.
# - multiple if - else condition but no nested one.

# %% [markdown]
# 13. What is the difference between for and while loops ?
# ---
# - for loop is used for iteration
# - While loop is used for applying condition

# %% [markdown]
# 14. Describe a scenario where a while loop is more suitable than a for loop.
# ---
# - When we use While loop , where we have to check condition or implement it
# - while a > 10:
#   print("a is greater")
#   a = a - 1
